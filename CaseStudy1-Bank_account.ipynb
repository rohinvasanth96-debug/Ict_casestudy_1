# %% [markdown]
# <a href="https://colab.research.google.com/github/rohinvasanth96-debug/Ict_casestudy_1/blob/main/CaseStudy1-Bank_account.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Case study 1-Bank Account

class Bank_account:

  def __init__(self,name,acno,bal):
    self.name=name
    self.acno=acno
    self.bal=bal

  #For withdrawal
  def withdraw (self,amt):
    self.amt=amt
    if self.amt>0:
      if self.amt<=self.bal:
        self.bal=self.bal-amt
        print(f' Amout withdrawn is {self.amt}. New balance is {self.bal}')
      else:
        print('insufficient balance')
    else:
      print("Invalid amount")

  #For deposit
  def deposit(self,amt):
    self.amt=amt
    if self.amt>0:
      self.bal=self.bal+self.amt
      print(f'Amount deposited is {self.amt}. New balace is {self.bal}')

    else:
      print("Invalid amount")

  #For balance enquiry
  def bal(bal):
    print(f'Your balance is {self.bal}')

#Creating objects

customer1=Bank_account('Rohin',101,1000)
customer2=Bank_account('Aswin',102,4000)

#Test
customer1.withdraw(100)
customer2.deposit(500)
print(f'Balance is {customer1.bal}')
# Out:
#  Amout withdrawn is 100. New balance is 900
# Amount deposited is 500. New balace is 4500
# Balance is 900
